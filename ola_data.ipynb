# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~%tebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~-tebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~=tebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~tebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~%tebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# ...

# %%
import pandas as pd 
file_path = r"C:\Users\pc\Downloads\Bookings-70000-Rows.xlsx"
df = pd.read_excel(file_path)
print(df.head())
# Out:
#                  Date      Time     Booking_ID        Booking_Status  \
# 0 2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1 2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2 2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3 2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4 2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
#
#   Customer_ID Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  \
# 0   CID713523  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN
# 1   CID225428         Bike     Magadi Road       Varthur  203.0   30.0
# 2   CID270156    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0
# 3   CID581320        eBike      HSR Layout   Vijayanagar    NaN    NaN
# 4   CID939555         Mini     Rajajinagar   Chamarajpet  252.0   80.0
#
#                      Canceled_Rides_by_Customer      Canceled_Rides_by_Driver  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
#        'Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'V_TAT', 'C_TAT',
#        'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
#        'Incomplete_Rides', 'Incomplete_Rides_Reason', 'Booking_Value',
#        'Payment_Method', 'Ride_Distance', 'Driver_Ratings', 'Customer_Rating',
#        'Vehicle Images'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                         26930
# C_TAT                         26930
# Canceled_Rides_by_Customer    63987
# Canceled_Rides_by_Driver      58473
# Incomplete_Rides              26930
# Incomplete_Rides_Reason       68516
# Booking_Value                     0
# Payment_Method                26930
# Ride_Distance                     0
# Driver_Ratings                26930
# Customer_Rating               26930
# Vehicle Images                    0
# dtype: int64

# %%
df.shape
# Out:
# (71201, 20)

# %%
df.drop_duplicates()
# Out:
#                      Date      Time     Booking_ID        Booking_Status  \
# 0     2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1     2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2     2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3     2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4     2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                   ...       ...            ...                   ...
# 71196 2024-07-19 09:48:00  09:48:00  CNR3193933852               Success
# 71197 2024-07-16 05:02:00  05:02:00  CNR3906366271               Success
# 71198 2024-07-03 22:14:00  22:14:00  CNR4789445170  Canceled by Customer
# 71199 2024-07-29 12:17:00  12:17:00  CNR5806198441    Canceled by Driver
# 71200 2024-07-19 21:38:00  21:38:00  CNR4531167950               Success
#
#       Customer_ID Vehicle_Type       Pickup_Location         Drop_Location  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71201 entries, 0 to 71200
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        71201 non-null  datetime64[ns]
#  1   Time                        71201 non-null  object
#  2   Booking_ID                  71201 non-null  object
#  3   Booking_Status              71201 non-null  object
#  4   Customer_ID                 71201 non-null  object
#  5   Vehicle_Type                71201 non-null  object
#  6   Pickup_Location             71201 non-null  object
#  7   Drop_Location               71201 non-null  object
#  8   V_TAT                       44271 non-null  float64
#  9   C_TAT                       44271 non-null  float64
#  10  Canceled_Rides_by_Customer  7214 non-null   object
#  11  Canceled_Rides_by_Driver    12728 non-null  object
#  12  Incomplete_Rides            44271 non-null  object
# ...

# %%
df["V_TAT"].fillna(df["V_TAT"].median(),inplace = True)
df["Payment_Method"].fillna(df["Payment_Method"].mode()[0],inplace = True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_3384\3945712216.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["V_TAT"].fillna(df["V_TAT"].median(),inplace = True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_3384\3945712216.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df["Canceled_Rides_by_Customer"].fillna(0,inplace = True)
df["Incomplete_Rides_Reason"].fillna("Unknown",inplace = True)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_3384\162843592.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Canceled_Rides_by_Customer"].fillna(0,inplace = True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_3384\162843592.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
 df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                             0
# C_TAT                         26930
# Canceled_Rides_by_Customer        0
# Canceled_Rides_by_Driver      58473
# Incomplete_Rides              26930
# Incomplete_Rides_Reason           0
# Booking_Value                     0
# Payment_Method                    0
# Ride_Distance                     0
# Driver_Ratings                26930
# Customer_Rating               26930
# Vehicle Images                    0
# dtype: int64

# %%
df["Driver_Ratings"].head()
# Out:
# 0    NaN
# 1    4.1
# 2    4.2
# 3    NaN
# 4    4.0
# Name: Driver_Ratings, dtype: float64

# %%
df["Driver_Ratings"] = df["Driver_Ratings"].fillna("Not Rating")
df["Customer_Rating"] = df["Customer_Rating"].fillna("Not Rating")

# %%
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                             0
# C_TAT                         26930
# Canceled_Rides_by_Customer        0
# Canceled_Rides_by_Driver      58473
# Incomplete_Rides              26930
# Incomplete_Rides_Reason           0
# Booking_Value                     0
# Payment_Method                    0
# Ride_Distance                     0
# Driver_Ratings                    0
# Customer_Rating                   0
# Vehicle Images                    0
# dtype: int64

# %%
df["Canceled_Rides_by_Driver"] = df["Canceled_Rides_by_Driver"].fillna(0)
df["Incomplete_Rides"] = df["Incomplete_Rides"].fillna(0)

# %%
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                             0
# C_TAT                         26930
# Canceled_Rides_by_Customer        0
# Canceled_Rides_by_Driver          0
# Incomplete_Rides                  0
# Incomplete_Rides_Reason           0
# Booking_Value                     0
# Payment_Method                    0
# Ride_Distance                     0
# Driver_Ratings                    0
# Customer_Rating                   0
# Vehicle Images                    0
# dtype: int64

# %%
df["C_TAT"] = df["C_TAT"].fillna(df["C_TAT"].median())

# %%
df.isnull().sum()
# Out:
# Date                          0
# Time                          0
# Booking_ID                    0
# Booking_Status                0
# Customer_ID                   0
# Vehicle_Type                  0
# Pickup_Location               0
# Drop_Location                 0
# V_TAT                         0
# C_TAT                         0
# Canceled_Rides_by_Customer    0
# Canceled_Rides_by_Driver      0
# Incomplete_Rides              0
# Incomplete_Rides_Reason       0
# Booking_Value                 0
# Payment_Method                0
# Ride_Distance                 0
# Driver_Ratings                0
# Customer_Rating               0
# Vehicle Images                0
# dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                      Date      Time     Booking_ID        Booking_Status  \
# 0     2024-07-26 14:00:00  14:00:00  CNR7153255142    Canceled by Driver
# 1     2024-07-25 22:20:00  22:20:00  CNR2940424040               Success
# 2     2024-07-30 19:59:00  19:59:00  CNR2982357879               Success
# 3     2024-07-22 03:15:00  03:15:00  CNR2395710036  Canceled by Customer
# 4     2024-07-02 09:02:00  09:02:00  CNR1797421769               Success
# ...                   ...       ...            ...                   ...
# 71196 2024-07-19 09:48:00  09:48:00  CNR3193933852               Success
# 71197 2024-07-16 05:02:00  05:02:00  CNR3906366271               Success
# 71198 2024-07-03 22:14:00  22:14:00  CNR4789445170  Canceled by Customer
# 71199 2024-07-29 12:17:00  12:17:00  CNR5806198441    Canceled by Driver
# 71200 2024-07-19 21:38:00  21:38:00  CNR4531167950               Success
#
# ...

# %%
import sys
# !{sys.executable} -m pip install --upgrade cryptograhy pymmysql sqlalchemy
print(sys.executable)
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python313\python.exe
# WARNING: Ignoring invalid distribution ~%tebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~-tebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~=tebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~~tebook (C:\Users\pc\AppData\Local\Programs\Python\Python313\Lib\site-packages)
# ERROR: Could not find a version that satisfies the requirement cryptograhy (from versions: none)
# ERROR: No matching distribution found for cryptograhy

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:YOURPASSWORD@localhost:3306/ola_project")
conn = engine.connect()
print("connected successfully")
# Out:
# connected successfully

# %%
df.to_sql(name='ola_data', con=engine, if_exists='append', index= False)
# Out:
# 71201

# %%
df
# Out:
# Date                          datetime64[ns]
# Time                                  object
# Booking_ID                            object
# Booking_Status                        object
# Customer_ID                           object
# Vehicle_Type                          object
# Pickup_Location                       object
# Drop_Location                         object
# V_TAT                                float64
# C_TAT                                float64
# Canceled_Rides_by_Customer            object
# Canceled_Rides_by_Driver              object
# Incomplete_Rides                      object
# Incomplete_Rides_Reason               object
# Booking_Value                          int64
# Payment_Method                        object
# Ride_Distance                          int64
# Driver_Ratings                        object
# Customer_Rating                       object
# Vehicle Images                        object
# dtype: object

# %%
df["Driver_Ratings"].dtype
# Out:
# dtype('O')

# %%
print(df["Driver_Ratings"].dtype)
# Out:
# object

# %%
df["Driver_Ratings"].unique()
# Out:
# array(['Not Rating', 4.1, 4.2, 4.0, 3.4, 3.2, 4.5, 3.9, 3.0, 4.8, 3.7,
#        3.3, 4.9, 4.3, 4.7, 3.1, 3.8, 3.5, 5.0, 4.6, 4.4, 3.6],
#       dtype=object)

# %%
import numpy as np 
df["Driver_Ratings"] = df["Driver_Ratings"].replace("Not Rating",np.nan)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_3384\3166061625.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Driver_Ratings"] = df["Driver_Ratings"].replace("Not Rating",np.nan)

# %%
df["Driver_Ratings"] = pd.to_numeric(df["Driver_Ratings"],errors = "coerce")

# %%
df["Driver_Ratings"].dtype
# Out:
# dtype('float64')

# %%
df["Driver_Ratings"].max()
# Out:
# np.float64(5.0)

# %%
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Booking_ID                        0
# Booking_Status                    0
# Customer_ID                       0
# Vehicle_Type                      0
# Pickup_Location                   0
# Drop_Location                     0
# V_TAT                             0
# C_TAT                             0
# Canceled_Rides_by_Customer        0
# Canceled_Rides_by_Driver          0
# Incomplete_Rides                  0
# Incomplete_Rides_Reason           0
# Booking_Value                     0
# Payment_Method                    0
# Ride_Distance                     0
# Driver_Ratings                26930
# Customer_Rating                   0
# Vehicle Images                    0
# dtype: int64

# %%
df.to_csv("ola_cleaned_data_76.csv")
